# %% [markdown]
# ## Using Pre-trained ResNet50 Model

# %%
# from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
# img_path = '/content/pets-4415649_640.jpg'
img_path = '/content/kangaroo-4361467_640.jpg'
img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
plt.show()

# %%
resnet50_model = ResNet50()

# %%
img_array = image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)
print(img_batch.shape)
img_preprocessed = preprocess_input(img_batch)
prediction = resnet50_model.predict(img_preprocessed)
print(prediction.shape)
decode_predictions(prediction, top=3)[0]
# Out:
# (1, 224, 224, 3)
# (1, 1000)
# [('n01877812', 'wallaby', 0.995387),
#  ('n02417914', 'ibex', 0.002110745),
#  ('n02326432', 'hare', 0.0019095523)]

# %% [markdown]
# ## Using Pre-trained VGG16 Model

# %%
from tensorflow.keras.applications import vgg16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
# img_path = '/content/pets-4415649_640.jpg'
img_path = '/content/kangaroo-4361467_640.jpg'
img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
plt.show()

# %%
vgg_model = vgg16.VGG16()

# %%
img_array = image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)
print(img_batch.shape)
img_preprocessed = preprocess_input(img_batch)
prediction = vgg_model.predict(img_preprocessed)
print(prediction.shape)
decode_predictions(prediction, top=3)[0]
# Out:
# (1, 224, 224, 3)
# (1, 1000)
# [('n01877812', 'wallaby', 0.9400826),
#  ('n02417914', 'ibex', 0.03083826),
#  ('n02326432', 'hare', 0.026960993)]
